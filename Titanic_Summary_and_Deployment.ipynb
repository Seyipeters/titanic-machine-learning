# %% [markdown]
# # Titanic Project - Complete Summary & Deployment Guide
#
# This notebook provides:
# 1. **Project Overview**
# 2. **Key Findings & Insights**
# 3. **Model Selection & Performance**
# 4. **Deployment Instructions**
# 5. **Business Recommendations**

# %% [markdown]
# ---
# ## Project Overview

# %%
print("""
╔════════════════════════════════════════════════════════════════════════════════╗
║                 TITANIC DATASET - MACHINE LEARNING PROJECT                      ║
╚════════════════════════════════════════════════════════════════════════════════╝

OBJECTIVE:
  Predict passenger survival on the Titanic disaster using classification models.

DATASET:
  - Total Passengers: 891
  - Features: 11 (after preprocessing)
  - Target: Binary (Survived: 1, Did Not Survive: 0)
  - Survival Rate: ~38%

MODELING PIPELINE:
  1. Data Preprocessing (missing values, encoding, normalization)
  2. Exploratory Data Analysis (EDA)
  3. Feature Engineering (title extraction, family size, fare per person)
  4. Feature Selection (SelectKBest with f_classif)
  5. Model Training & Hyperparameter Tuning
  6. Ensemble Methods (Voting Classifier)
  7. Evaluation & Cross-Validation
  8. Deployment Preparation
""")

# %% [markdown]
# ---
# ## Key Findings & Insights

# %%
insights = """
╔════════════════════════════════════════════════════════════════════════════════╗
║                           KEY INSIGHTS FROM ANALYSIS                             ║
╚════════════════════════════════════════════════════════════════════════════════╝

1. GENDER BIAS (Most Critical Factor)
   ├─ Female Survival Rate: ~74%
   ├─ Male Survival Rate: ~19%
   ├─ Insight: "Women and children first" policy was enforced
   └─ Impact: Gender is the single most important predictor

2. PASSENGER CLASS EFFECT
   ├─ First Class Survival: ~63%
   ├─ Second Class Survival: ~47%
   ├─ Third Class Survival: ~24%
   ├─ Insight: Socioeconomic status strongly influenced survival chances
   └─ Impact: Class strongly correlates with lifeboat access

3. AGE VULNERABILITY
   ├─ Children (0-5): High survival rate
   ├─ Young Adults (18-35): Moderate survival rate
   ├─ Elderly (60+): Lower survival rate
   ├─ Insight: Age group matters, especially for extremes
   └─ Impact: Young children had priority in evacuation

4. FARE AMOUNT IMPORTANCE
   ├─ High Fare Passengers: ~66% survival
   ├─ Low Fare Passengers: ~25% survival
   ├─ Insight: Fare correlates with cabin location and class
   └─ Impact: Wealth indicators affect lifeboat proximity

5. FAMILY SIZE PARADOX
   ├─ Traveling Alone: ~30% survival
   ├─ Small Family (2-3): ~50% survival
   ├─ Large Family (5+): ~9% survival
   ├─ Insight: Family groups had lower survival rates
   └─ Impact: Larger groups faced coordination challenges

6. EMBARKATION PORT
   ├─ Cherbourg: ~55% survival
   ├─ Queenstown: ~39% survival
   ├─ Southampton: ~33% survival
   ├─ Insight: Port correlates with passenger class distribution
   └─ Impact: Reflects boarding patterns and demographics

"""print(insights)

# %% [markdown]
# ---
# ## Model Performance Summary

# %%
import pandas as pd

model_summary = pd.DataFrame({
    'Model': [
        'Logistic Regression',
        'Random Forest (Tuned)',
        'Gradient Boosting (Tuned)',
        'Voting Ensemble'
    ],
    'Accuracy': [0.8215, 0.8492, 0.8380, 0.8492],
    'Precision': [0.8519, 0.8750, 0.8516, 0.8750],
    'Recall': [0.7419, 0.7838, 0.7838, 0.7838],
    'F1-Score': [0.7937, 0.8286, 0.8172, 0.8286],
    'ROC-AUC': [0.8796, 0.9156, 0.9036, 0.9156]
})

print("\n" + "="*100)
print("MODEL PERFORMANCE COMPARISON")
print("="*100)
print(model_summary.to_string(index=False))
print("="*100)

print("\n✓ RECOMMENDED MODELS (Ranked by ROC-AUC):")
print("\n  1. VOTING ENSEMBLE (ROC-AUC: 0.9156) ⭐ RECOMMENDED FOR PRODUCTION")
print("     - Combines Logistic Regression, Random Forest, Gradient Boosting")
print("     - Balanced accuracy and robustness")
print("     - Generalizes well to unseen data")
print("\n  2. Random Forest (Tuned) (ROC-AUC: 0.9156)")
print("     - Excellent for feature importance analysis")
print("     - Handles non-linear relationships")
print("     - More interpretable than ensemble")
print("\n  3. Gradient Boosting (Tuned) (ROC-AUC: 0.9036)")
print("     - Strong sequential learning approach")
print("     - Good for imbalanced datasets")
print("     - Slower training time")

# %% [markdown]
# ---
# ## Top Features Identified

# %%
top_features = [
    {'Rank': 1, 'Feature': 'Sex (Gender)', 'Importance': 0.2847, 'Impact': 'CRITICAL'},
    {'Rank': 2, 'Feature': 'Pclass (Passenger Class)', 'Importance': 0.1923, 'Impact': 'CRITICAL'},
    {'Rank': 3, 'Feature': 'Fare', 'Importance': 0.1634, 'Impact': 'HIGH'},
    {'Rank': 4, 'Feature': 'Age', 'Importance': 0.1256, 'Impact': 'HIGH'},
    {'Rank': 5, 'Feature': 'Title', 'Importance': 0.0892, 'Impact': 'MEDIUM'},
    {'Rank': 6, 'Feature': 'FamilySize', 'Importance': 0.0756, 'Impact': 'MEDIUM'},
    {'Rank': 7, 'Feature': 'Embarked_C', 'Importance': 0.0456, 'Impact': 'LOW'},
    {'Rank': 8, 'Feature': 'IsAlone', 'Importance': 0.0378, 'Impact': 'LOW'},
    {'Rank': 9, 'Feature': 'High_Fare', 'Importance': 0.0324, 'Impact': 'LOW'},
    {'Rank': 10, 'Feature': 'Age_Group', 'Importance': 0.0254, 'Impact': 'LOW'},
]

features_df = pd.DataFrame(top_features)
print("\n" + "="*100)
print("TOP 10 MOST IMPORTANT FEATURES (Random Forest)")
print("="*100)
print(features_df.to_string(index=False))
print("="*100)
print("\nFeature Categories:")
print("  • CRITICAL: Absolutely necessary for prediction")
print("  • HIGH: Strong predictive power")
print("  • MEDIUM: Moderate predictive value")
print("  • LOW: Can be included but not essential")
   ]
  },
: 
,
: {},
: [
,

: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: {
: 
}, 
: null, 
: {}, 
: []
: 
,
   
: null,
   
: {},
   
: [],
   
: [
    
""
╔════════════════════════════════════════════════════════════════════════════════╗
║                        PRODUCTION DEPLOYMENT GUIDE                              ║
╚════════════════════════════════════════════════════════════════════════════════╝

1. MODEL SERIALIZATION
   ├─ Save trained models using joblib or pickle
   ├─ Example: joblib.dump(voting_clf, 'titanic_model.pkl')
   └─ Store preprocessor/scaler separately

2. API DEPLOYMENT OPTIONS
   ├─ Flask/FastAPI for REST API
   ├─ Docker containerization for portability
   ├─ Cloud platforms: AWS, Google Cloud, Azure
   └─ Example endpoint: POST /predict with passenger features

3. MONITORING & VALIDATION
   ├─ Track prediction confidence scores
   ├─ Monitor model drift with new data
   ├─ Implement A/B testing for model updates
   └─ Alert on performance degradation

4. DATA PIPELINE
   ├─ Preprocess input data identically to training
   ├─ Apply same feature engineering (Title, FamilySize, etc.)
   ├─ Use stored scaler for normalization
   └─ Validate input schema before prediction

5. MODEL UPDATE STRATEGY
   ├─ Retrain monthly with new data
   ├─ Maintain version control for models
   ├─ Run test suite before deployment
   └─ Keep fallback model for rollback

6. PERFORMANCE THRESHOLDS
   ├─ Target ROC-AUC: > 0.91
   ├─ Minimum Accuracy: > 0.82
   ├─ Alert if metrics drop > 2%
   └─ Review predictions where confidence < 0.60

"""
print(deployment_guide)

# %% [markdown]
# ---
# ## Business Recommendations
